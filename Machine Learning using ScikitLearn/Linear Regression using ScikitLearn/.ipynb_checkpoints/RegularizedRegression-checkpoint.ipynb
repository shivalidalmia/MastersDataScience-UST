# %%
# Regularized Regression
# We will now be importing some required libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#Loading the dataset
dataset = pd.read_csv('salary2.csv')

X = dataset.iloc[:,1:2].values #We are not using column 1. Also we slice it this way because we want X to be a matrix
y = dataset.iloc[:,2].values


#Polynomial Regression with No Regularization
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
polyFeatureObj = PolynomialFeatures(degree=10)
X_poly = polyFeatureObj.fit_transform(X)
prObj = LinearRegression()
prObj.fit(X_poly, y)


#Polynomial Regression with Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
polyFeatureObj = PolynomialFeatures(degree=10)
X_poly = polyFeatureObj.fit_transform(X)
ridgeObj = Ridge()
ridgeObj.fit(X_poly, y)

#Polynomial Regression with Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso
polyFeatureObj = PolynomialFeatures(degree=10)
X_poly = polyFeatureObj.fit_transform(X)
lassoObj = Lasso()
lassoObj.fit(X_poly, y)

#Polynomial Regression with ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import ElasticNet
polyFeatureObj = PolynomialFeatures(degree=10)
X_poly = polyFeatureObj.fit_transform(X)
enObj = ElasticNet(l1_ratio=0)
enObj.fit(X_poly, y)


#Visualizing Results of Polynomial Regression
plt.scatter(X, y, color='red')
plt.plot(X, prObj.predict(X_poly), color='blue')
plt.title('Results of Polynomial Regression Model')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()

#Visualizing Results of Ridge Regression
plt.scatter(X, y, color='red')
plt.plot(X, ridgeObj.predict(X_poly), color='blue')
plt.title('Results of Ridge Regression Model')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()

#Visualizing Results of Lasso Regression
plt.scatter(X, y, color='red')
plt.plot(X, lassoObj.predict(X_poly), color='blue')
plt.title('Results of Lasso Regression Model')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()

#Visualizing Results of ElasticNet Regression
plt.scatter(X, y, color='red')
plt.plot(X, enObj.predict(X_poly), color='blue')
plt.title('Results of ElasticNet Regression Model')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\manje\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\manje\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25272530827.872807, tolerance: 17845160.0
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\manje\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28945872669.530407, tolerance: 17845160.0
#   model = cd_fast.enet_coordinate_descent(
