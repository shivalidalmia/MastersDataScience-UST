# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls 'drive/MyDrive/SEIS764'
# Out:
# 1-SimpleNN.ipynb  2-RegressionNN.ipynb	examScores.csv

# %%
dataset = pd.read_csv("drive/MyDrive/SEIS764/examScores.csv").values

# %%
X = dataset[:,0].reshape(-1,1)
y = dataset[:,1]

# %%
plt.scatter(X,y)

# %%
# Fitting linear regression using sklearn
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X,y)
# Out:
# LinearRegression()

# %%
# Simple linear regression prediction
regressor.predict([[5.5]])
# Out:
# array([56.25059205])

# %%
# Weight for X
regressor.coef_
# Out:
# array([9.77580339])

# %%
# Bias term
regressor.intercept_
# Out:
# 2.48367340537321

# %%
# Regression with tensorflow
import tensorflow as tf
from tensorflow import keras

# %%
model = tf.keras.Sequential(
    [keras.layers.Dense(units = 1, input_shape =[1])]
)

# %%
model.compile(optimizer='sgd',loss='mean_squared_error') #default learning rate

# %%
#Specifying our learning rate and momentum for SGD
#model.compile(optimizer=tf.keras.optimizers.SGD(0.01,0.9),loss='mean_squared_error') #passing moemtum of 0.9 and learning rate of 0.9
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
# Learning rate scheduler 
def schedule(epoch,lr):
  if epoch >= 50:
    return 0.0001
  return 0.001

# %%
#scheduler = tf.keras.callbacks.LearningRateScheduler(schedule)
#r=model.fit(X,y,epochs=200,callbacks=[scheduler])  #this is used when we want to have low learning rate for strating epochs and high in later cases

# %%
r = model.fit(X, y, epochs= 200) #captures performance history per epoch so that we plot it later
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 354ms/step - loss: 28.8827
# Epoch 2/200
# 1/1 [==============================] - 0s 9ms/step - loss: 28.8828
# Epoch 3/200
# 1/1 [==============================] - 0s 12ms/step - loss: 28.8827
# Epoch 4/200
# 1/1 [==============================] - 0s 16ms/step - loss: 28.8827
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 28.8828
# Epoch 6/200
# 1/1 [==============================] - 0s 18ms/step - loss: 28.8827
# Epoch 7/200
# 1/1 [==============================] - 0s 10ms/step - loss: 28.8827
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 28.8827
# Epoch 9/200
# 1/1 [==============================] - 0s 8ms/step - loss: 28.8827
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 28.8827
# Epoch 11/200
# 1/1 [==============================] - 0s 11ms/step - loss: 28.8827
# Epoch 12/200
# ...

# %%
print(model.layers[0].get_weights())
# Out:
# [array([[9.775804]], dtype=float32), array([2.4836721], dtype=float32)]

# %%
plt.plot(r.history['loss'])

# %%
model.predict([[5.5]])
# Out:
# array([[56.25059]], dtype=float32)
